# %%
import pandas as pd

# %%
# 점수 입력
data = {
    '3P' : [3.4],
    'BLK' : [0.5],
    'TRB' : [3.7]
}
df= pd.DataFrame(data)
df
# Out:
#     3P  BLK  TRB
# 0  3.4  0.5  3.7

# %%
import joblib
knn = joblib.load('../Data/knn_basketball.h5')

pred = knn.predict(df)
print(f"추천하는 포지션은 {pred[0]} 입니다.")
# Out:
# 추천하는 포지션은 SG 입니다.
